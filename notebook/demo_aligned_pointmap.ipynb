# %%
# Copyright (c) Meta Platforms, Inc. and affiliates.

# %% [markdown]
# ## 1. Imports and Model Loading

# %%
import os
import sys

# 设置 CUDA_HOME 环境变量（gsplat 需要这个来检测 CUDA toolkit）
# 必须在导入任何使用 gsplat 的模块之前设置
os.environ["CUDA_HOME"] = os.environ.get("CONDA_PREFIX", "")
os.environ["LIDRA_SKIP_INIT"] = "true"

# 添加项目根目录到 Python 路径，以便导入 sam3d_objects
project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))
if project_root not in sys.path:
    sys.path.insert(0, project_root)


import uuid
import imageio
import numpy as np
import torch
from IPython.display import Image as ImageDisplay

# 验证 gsplat CUDA 支持
try:
    import gsplat
    import gsplat.cuda._backend
    _C = getattr(gsplat.cuda._backend, '_C', None)
    if _C is not None:
        print("✓ gsplat CUDA 扩展已正确加载")
    else:
        print("⚠ 警告: gsplat CUDA 扩展未加载，渲染可能失败")
except Exception as e:
    print(f"⚠ gsplat 导入警告: {e}")

from inference import Inference, ready_gaussian_for_video_rendering, load_image, load_masks, display_image, make_scene, render_video, interactive_visualizer
# Out:
# ✓ gsplat CUDA 扩展已正确加载
# 2025-12-06 15:08:28.519 | INFO     | sam3d_objects.pipeline.inference_pipeline:set_attention_backend:15 - GPU name is NVIDIA GeForce RTX 5090
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.
# 2025-12-06 15:08:29.296 | INFO     | sam3d_objects.model.backbone.tdfy_dit.modules.sparse:__from_env:39 - [SPARSE] Backend: spconv, Attention: sdpa
# /home/ubuntu/miniconda3/envs/sam3d/lib/python3.11/site-packages/spconv/pytorch/functional.py:47: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   _TORCH_CUSTOM_FWD = amp.custom_fwd(cast_inputs=torch.float16)
# /home/ubuntu/miniconda3/envs/sam3d/lib/python3.11/site-packages/spconv/pytorch/functional.py:96: FutureWarning: `torch.cuda.amp.custom_bwd(args...)` is deprecated. Please use `torch.amp.custom_bwd(args..., device_type='cuda')` instead.
#   @_TORCH_CUSTOM_BWD
# /home/ubuntu/miniconda3/envs/sam3d/lib/python3.11/site-packages/spconv/pytorch/functional.py:162: FutureWarning: `torch.cuda.amp.custom_bwd(args...)` is deprecated. Please use `torch.amp.custom_bwd(args..., device_type='cuda')` instead.
#   @_TORCH_CUSTOM_BWD
# /home/ubuntu/miniconda3/envs/sam3d/lib/python3.11/site-packages/spconv/pytorch/functional.py:242: FutureWarning: `torch.cuda.amp.custom_bwd(args...)` is deprecated. Please use `torch.amp.custom_bwd(args..., device_type='cuda')` instead.
#   @_TORCH_CUSTOM_BWD
# /home/ubuntu/miniconda3/envs/sam3d/lib/python3.11/site-packages/spconv/pytorch/functional.py:331: FutureWarning: `torch.cuda.amp.custom_bwd(args...)` is deprecated. Please use `torch.amp.custom_bwd(args..., device_type='cuda')` instead.
#   @_TORCH_CUSTOM_BWD
# /home/ubuntu/miniconda3/envs/sam3d/lib/python3.11/site-packages/spconv/pytorch/functional.py:368: FutureWarning: `torch.cuda.amp.custom_bwd(args...)` is deprecated. Please use `torch.amp.custom_bwd(args..., device_type='cuda')` instead.
#   @_TORCH_CUSTOM_BWD
# /home/ubuntu/miniconda3/envs/sam3d/lib/python3.11/site-packages/spconv/pytorch/functional.py:388: FutureWarning: `torch.cuda.amp.custom_bwd(args...)` is deprecated. Please use `torch.amp.custom_bwd(args..., device_type='cuda')` instead.
#   @_TORCH_CUSTOM_BWD
# /home/ubuntu/miniconda3/envs/sam3d/lib/python3.11/site-packages/spconv/pytorch/functional.py:411: FutureWarning: `torch.cuda.amp.custom_bwd(args...)` is deprecated. Please use `torch.amp.custom_bwd(args..., device_type='cuda')` instead.
#   @_TORCH_CUSTOM_BWD
# 2025-12-06 15:08:31.355 | INFO     | sam3d_objects.model.backbone.tdfy_dit.modules.attention:__from_env:30 - [ATTENTION] Using backend: sdpa
# [SPARSE][CONV] spconv algo: auto
# 2025-12-06 15:08:31.715 | WARNING  | sam3d_objects.data.dataset.tdfy.preprocessor:__post_init__:51 - No rgb pointmap normalizer provided, using scale + shift
# 2025-12-06 15:08:31.715 | WARNING  | sam3d_objects.data.dataset.tdfy.preprocessor:__post_init__:51 - No rgb pointmap normalizer provided, using scale + shift

# %%
PATH = os.getcwd()
TAG = "hf"
config_path = f"{PATH}/../checkpoints/{TAG}/pipeline.yaml"
inference = Inference(config_path, compile=False)
# Out:
# 2025-12-06 15:08:31.742 | WARNING  | sam3d_objects.data.dataset.tdfy.preprocessor:__post_init__:51 - No rgb pointmap normalizer provided, using scale + shift
# /home/ubuntu/miniconda3/envs/sam3d/lib/python3.11/site-packages/moge/model/v1.py:171: UserWarning: The following deprecated/invalid arguments are ignored: {'output_mask': True, 'split_head': True}
#   warnings.warn(f"The following deprecated/invalid arguments are ignored: {deprecated_kwargs}")
# 2025-12-06 15:08:45.416 | WARNING  | sam3d_objects.data.dataset.tdfy.preprocessor:__post_init__:51 - No rgb pointmap normalizer provided, using scale + shift
# 2025-12-06 15:08:45.417 | INFO     | sam3d_objects.pipeline.inference_pipeline:__init__:98 - self.device: cuda
# 2025-12-06 15:08:45.417 | INFO     | sam3d_objects.pipeline.inference_pipeline:__init__:99 - CUDA_VISIBLE_DEVICES: None
# 2025-12-06 15:08:45.418 | INFO     | sam3d_objects.pipeline.inference_pipeline:__init__:100 - Actually using GPU: 0
# 2025-12-06 15:08:45.418 | INFO     | sam3d_objects.pipeline.inference_pipeline:init_pose_decoder:295 - Using pose decoder: ScaleShiftInvariant
# 2025-12-06 15:08:45.419 | INFO     | sam3d_objects.pipeline.inference_pipeline:__init__:131 - Loading model weights...
# 2025-12-06 15:08:45.532 | INFO     | sam3d_objects.model.io:load_model_from_checkpoint:158 - Loading checkpoint from /home/ubuntu/sam-3d-objects/notebook/../checkpoints/hf/ss_generator.ckpt
# 2025-12-06 15:08:50.368 | INFO     | sam3d_objects.model.io:load_model_from_checkpoint:158 - Loading checkpoint from /home/ubuntu/sam-3d-objects/notebook/../checkpoints/hf/slat_generator.ckpt
# 2025-12-06 15:08:51.449 | INFO     | sam3d_objects.model.io:load_model_from_checkpoint:158 - Loading checkpoint from /home/ubuntu/sam-3d-objects/notebook/../checkpoints/hf/ss_decoder.ckpt
# 2025-12-06 15:08:51.612 | INFO     | sam3d_objects.model.io:load_model_from_checkpoint:158 - Loading checkpoint from /home/ubuntu/sam-3d-objects/notebook/../checkpoints/hf/slat_decoder_gs.ckpt
# 2025-12-06 15:08:51.698 | INFO     | sam3d_objects.model.io:load_model_from_checkpoint:158 - Loading checkpoint from /home/ubuntu/sam-3d-objects/notebook/../checkpoints/hf/slat_decoder_gs_4.ckpt
# 2025-12-06 15:08:51.797 | INFO     | sam3d_objects.model.io:load_model_from_checkpoint:158 - Loading checkpoint from /home/ubuntu/sam-3d-objects/notebook/../checkpoints/hf/slat_decoder_mesh.ckpt
# 2025-12-06 15:08:51.933 | INFO     | sam3d_objects.model.backbone.dit.embedder.dino:__init__:31 - Loading DINO model: dinov2_vitl14_reg from facebookresearch/dinov2 (source: github)
# 2025-12-06 15:08:53.101 | INFO     | sam3d_objects.model.backbone.dit.embedder.dino:__init__:44 - Loaded DINO model - type: <class 'dinov2.models.vision_transformer.DinoVisionTransformer'>, embed_dim: 1024, patch_size: (14, 14)
# 2025-12-06 15:08:53.103 | INFO     | sam3d_objects.model.backbone.dit.embedder.dino:__init__:31 - Loading DINO model: dinov2_vitl14_reg from facebookresearch/dinov2 (source: github)
# 2025-12-06 15:08:53.793 | INFO     | sam3d_objects.model.backbone.dit.embedder.dino:__init__:44 - Loaded DINO model - type: <class 'dinov2.models.vision_transformer.DinoVisionTransformer'>, embed_dim: 1024, patch_size: (14, 14)
# 2025-12-06 15:08:53.801 | INFO     | sam3d_objects.model.io:load_model_from_checkpoint:158 - Loading checkpoint from /home/ubuntu/sam-3d-objects/notebook/../checkpoints/hf/ss_generator.ckpt
# 2025-12-06 15:08:55.453 | INFO     | sam3d_objects.model.backbone.dit.embedder.dino:__init__:31 - Loading DINO model: dinov2_vitl14_reg from facebookresearch/dinov2 (source: github)
# 2025-12-06 15:08:56.069 | INFO     | sam3d_objects.model.backbone.dit.embedder.dino:__init__:44 - Loaded DINO model - type: <class 'dinov2.models.vision_transformer.DinoVisionTransformer'>, embed_dim: 1024, patch_size: (14, 14)
# 2025-12-06 15:08:56.072 | INFO     | sam3d_objects.model.backbone.dit.embedder.dino:__init__:31 - Loading DINO model: dinov2_vitl14_reg from facebookresearch/dinov2 (source: github)
# 2025-12-06 15:08:56.772 | INFO     | sam3d_objects.model.backbone.dit.embedder.dino:__init__:44 - Loaded DINO model - type: <class 'dinov2.models.vision_transformer.DinoVisionTransformer'>, embed_dim: 1024, patch_size: (14, 14)
# 2025-12-06 15:08:56.776 | INFO     | sam3d_objects.model.io:load_model_from_checkpoint:158 - Loading checkpoint from /home/ubuntu/sam-3d-objects/notebook/../checkpoints/hf/slat_generator.ckpt
# 2025-12-06 15:08:58.059 | INFO     | sam3d_objects.pipeline.inference_pipeline:override_ss_generator_cfg_config:436 - ss_generator parameters: inference_steps=25, cfg_strength=7, cfg_interval=[0, 500], rescale_t=3, cfg_strength_pm=0.0
# 2025-12-06 15:08:58.060 | INFO     | sam3d_objects.pipeline.inference_pipeline:override_slat_generator_cfg_config:458 - slat_generator parameters: inference_steps=25, cfg_strength=1, cfg_interval=[0, 500], rescale_t=1
# 2025-12-06 15:08:58.060 | INFO     | sam3d_objects.pipeline.inference_pipeline:__init__:196 - Loading model weights completed!

# %% [markdown]
# ## 2. Load input image to lift to 3D (multiple objects)

# %%
IMAGE_PATH = f"{PATH}/images/nocs_0003_0354/rgb.png"
IMAGE_NAME = os.path.basename(os.path.dirname(IMAGE_PATH))

image = load_image(IMAGE_PATH)
masks = load_masks(os.path.dirname(IMAGE_PATH), extension=".png")
display_image(image, masks)
# Out:
# /home/ubuntu/sam-3d-objects/notebook/inference.py:404: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %% [markdown]
# ## 3. Generating Pointmap from Depth Image

# %%
import imageio.v3 as iio

depth_path = f"{PATH}/images/nocs_0003_0354/depth.png"
depth = iio.imread(depth_path).astype(np.float32)
depth = depth / 1000.0 #convert to mm -> m
depth[depth <= 0] = np.nan  

H, W = depth.shape

K = np.array([
    [591.012500, 0.0,      322.525000],
    [0.0,        590.167750, 244.110840],
    [0.0,        0.0,        1.0]
], dtype=np.float32)

fx = K[0, 0]
fy = K[1, 1]
cx = K[0, 2]
cy = K[1, 2]

# ------------------ PIXEL GRID ------------------
u = np.arange(W)
v = np.arange(H)
uu, vv = np.meshgrid(u, v)

Z = depth
X = (uu - cx) * Z / fx
Y = (vv - cy) * Z / fy

# ---------------------------------------------------------------------
# Convert image coordinates (x→right, y→down) into PyTorch3D coordinates:
#   PyTorch3D expects a right-handed camera frame with:
#       +x → right, +y → UP, +z → forward.
#   So we flip both X and Y:
#       -Y  converts image Y-down into Y-up,
#       -X  keeps the coordinate system right-handed.
# ---------------------------------------------------------------------

pointmap = np.stack([-X, -Y, Z], axis=-1)
pointmaP = torch.tensor(pointmap, dtype=torch.float32)

# %% [markdown]
# ## 4. Generate Gaussian Splats

# %%
outputs = [inference(image, mask, seed=42,pointmap=pointmaP) for mask in masks]
# Out:
# 2025-12-06 15:08:58.570 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:662 - Sampling sparse structure: inference_steps=25, strength=7, interval=[0, 500], rescale_t=3, cfg_strength_pm=0.0
# 2025-12-06 15:08:58.570 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:631 - Running condition embedder ...
# 2025-12-06 15:08:58.730 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:635 - Condition embedder finishes!
# 2025-12-06 15:09:02.036 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:712 - Downsampled coords from 7708 to 7708
# 2025-12-06 15:09:02.059 | INFO     | sam3d_objects.pipeline.inference_pipeline_pointmap:run:368 - Rescaling scale by 1 after downsampling
# 2025-12-06 15:09:02.059 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_slat:742 - Sampling sparse latent: inference_steps=25, strength=1, interval=[0, 500], rescale_t=1
# 2025-12-06 15:09:02.060 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:631 - Running condition embedder ...
# 2025-12-06 15:09:02.085 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:635 - Condition embedder finishes!
# 2025-12-06 15:09:04.309 | INFO     | sam3d_objects.pipeline.inference_pipeline:decode_slat:604 - Decoding sparse latent...
# 2025-12-06 15:09:06.415 | INFO     | sam3d_objects.pipeline.inference_pipeline:postprocess_slat_output:538 - Postprocessing mesh with option with_mesh_postprocess False, with_texture_baking False...
# 2025-12-06 15:09:06.423 | INFO     | sam3d_objects.pipeline.inference_pipeline_pointmap:run:416 - Finished!
# 2025-12-06 15:09:06.718 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:662 - Sampling sparse structure: inference_steps=25, strength=7, interval=[0, 500], rescale_t=3, cfg_strength_pm=0.0
# 2025-12-06 15:09:06.719 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:631 - Running condition embedder ...
# 2025-12-06 15:09:06.766 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:635 - Condition embedder finishes!
# 2025-12-06 15:09:10.047 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:712 - Downsampled coords from 14860 to 14860
# 2025-12-06 15:09:10.051 | INFO     | sam3d_objects.pipeline.inference_pipeline_pointmap:run:368 - Rescaling scale by 1 after downsampling
# 2025-12-06 15:09:10.051 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_slat:742 - Sampling sparse latent: inference_steps=25, strength=1, interval=[0, 500], rescale_t=1
# 2025-12-06 15:09:10.051 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:631 - Running condition embedder ...
# 2025-12-06 15:09:10.078 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:635 - Condition embedder finishes!
# 2025-12-06 15:09:12.680 | INFO     | sam3d_objects.pipeline.inference_pipeline:decode_slat:604 - Decoding sparse latent...
# 2025-12-06 15:09:12.991 | INFO     | sam3d_objects.pipeline.inference_pipeline:postprocess_slat_output:538 - Postprocessing mesh with option with_mesh_postprocess False, with_texture_baking False...
# 2025-12-06 15:09:13.001 | INFO     | sam3d_objects.pipeline.inference_pipeline_pointmap:run:416 - Finished!
# 2025-12-06 15:09:13.275 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:662 - Sampling sparse structure: inference_steps=25, strength=7, interval=[0, 500], rescale_t=3, cfg_strength_pm=0.0
# 2025-12-06 15:09:13.276 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:631 - Running condition embedder ...
# 2025-12-06 15:09:13.323 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:635 - Condition embedder finishes!
# 2025-12-06 15:09:16.586 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:712 - Downsampled coords from 13569 to 12634
# 2025-12-06 15:09:16.590 | INFO     | sam3d_objects.pipeline.inference_pipeline_pointmap:run:368 - Rescaling scale by 1 after downsampling
# 2025-12-06 15:09:16.590 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_slat:742 - Sampling sparse latent: inference_steps=25, strength=1, interval=[0, 500], rescale_t=1
# 2025-12-06 15:09:16.591 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:631 - Running condition embedder ...
# 2025-12-06 15:09:16.615 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:635 - Condition embedder finishes!
# 2025-12-06 15:09:18.715 | INFO     | sam3d_objects.pipeline.inference_pipeline:decode_slat:604 - Decoding sparse latent...
# 2025-12-06 15:09:18.964 | INFO     | sam3d_objects.pipeline.inference_pipeline:postprocess_slat_output:538 - Postprocessing mesh with option with_mesh_postprocess False, with_texture_baking False...
# 2025-12-06 15:09:18.975 | INFO     | sam3d_objects.pipeline.inference_pipeline_pointmap:run:416 - Finished!
# 2025-12-06 15:09:19.269 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:662 - Sampling sparse structure: inference_steps=25, strength=7, interval=[0, 500], rescale_t=3, cfg_strength_pm=0.0
# 2025-12-06 15:09:19.270 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:631 - Running condition embedder ...
# 2025-12-06 15:09:19.318 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:635 - Condition embedder finishes!
# 2025-12-06 15:09:22.545 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:712 - Downsampled coords from 22386 to 22267
# 2025-12-06 15:09:22.548 | INFO     | sam3d_objects.pipeline.inference_pipeline_pointmap:run:368 - Rescaling scale by 1 after downsampling
# 2025-12-06 15:09:22.549 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_slat:742 - Sampling sparse latent: inference_steps=25, strength=1, interval=[0, 500], rescale_t=1
# 2025-12-06 15:09:22.550 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:631 - Running condition embedder ...
# 2025-12-06 15:09:22.576 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:635 - Condition embedder finishes!
# 2025-12-06 15:09:26.211 | INFO     | sam3d_objects.pipeline.inference_pipeline:decode_slat:604 - Decoding sparse latent...
# 2025-12-06 15:09:26.811 | INFO     | sam3d_objects.pipeline.inference_pipeline:postprocess_slat_output:538 - Postprocessing mesh with option with_mesh_postprocess False, with_texture_baking False...
# 2025-12-06 15:09:26.826 | INFO     | sam3d_objects.pipeline.inference_pipeline_pointmap:run:416 - Finished!
# 2025-12-06 15:09:26.967 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:662 - Sampling sparse structure: inference_steps=25, strength=7, interval=[0, 500], rescale_t=3, cfg_strength_pm=0.0
# 2025-12-06 15:09:26.967 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:631 - Running condition embedder ...
# 2025-12-06 15:09:27.014 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:635 - Condition embedder finishes!
# 2025-12-06 15:09:30.266 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:712 - Downsampled coords from 23918 to 23104
# 2025-12-06 15:09:30.269 | INFO     | sam3d_objects.pipeline.inference_pipeline_pointmap:run:368 - Rescaling scale by 1 after downsampling
# 2025-12-06 15:09:30.270 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_slat:742 - Sampling sparse latent: inference_steps=25, strength=1, interval=[0, 500], rescale_t=1
# 2025-12-06 15:09:30.273 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:631 - Running condition embedder ...
# 2025-12-06 15:09:30.299 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:635 - Condition embedder finishes!
# 2025-12-06 15:09:34.456 | INFO     | sam3d_objects.pipeline.inference_pipeline:decode_slat:604 - Decoding sparse latent...
# 2025-12-06 15:09:35.090 | INFO     | sam3d_objects.pipeline.inference_pipeline:postprocess_slat_output:538 - Postprocessing mesh with option with_mesh_postprocess False, with_texture_baking False...
# 2025-12-06 15:09:35.107 | INFO     | sam3d_objects.pipeline.inference_pipeline_pointmap:run:416 - Finished!
# 2025-12-06 15:09:35.289 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:662 - Sampling sparse structure: inference_steps=25, strength=7, interval=[0, 500], rescale_t=3, cfg_strength_pm=0.0
# 2025-12-06 15:09:35.290 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:631 - Running condition embedder ...
# 2025-12-06 15:09:35.338 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:635 - Condition embedder finishes!
# 2025-12-06 15:09:38.619 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:712 - Downsampled coords from 22287 to 22270
# 2025-12-06 15:09:38.623 | INFO     | sam3d_objects.pipeline.inference_pipeline_pointmap:run:368 - Rescaling scale by 1 after downsampling
# 2025-12-06 15:09:38.624 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_slat:742 - Sampling sparse latent: inference_steps=25, strength=1, interval=[0, 500], rescale_t=1
# 2025-12-06 15:09:38.624 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:631 - Running condition embedder ...
# 2025-12-06 15:09:38.653 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:635 - Condition embedder finishes!
# 2025-12-06 15:09:42.180 | INFO     | sam3d_objects.pipeline.inference_pipeline:decode_slat:604 - Decoding sparse latent...
# 2025-12-06 15:09:42.832 | INFO     | sam3d_objects.pipeline.inference_pipeline:postprocess_slat_output:538 - Postprocessing mesh with option with_mesh_postprocess False, with_texture_baking False...
# 2025-12-06 15:09:42.847 | INFO     | sam3d_objects.pipeline.inference_pipeline_pointmap:run:416 - Finished!

# %% [markdown]
# ## 5. Mesh Alignment & Coordinate Frame Conversion

# %%
from pytorch3d.transforms import quaternion_to_matrix, Transform3d

# Z-up → Y-up conversion
R_zup_to_yup = torch.tensor([
    [-1, 0, 0],
    [0, 0, 1],
    [0, 1, 0],
], dtype=torch.float32)

R_yup_to_zup = R_zup_to_yup.T

# flip Z-axis 
R_flip_z = torch.tensor([
    [1, 0, 0],
    [ 0, 1, 0],
    [ 0, 0, -1],
], dtype=torch.float32)

# Convert from pointmap convention [-X, -Y, Z] back to true
R_pytorch3d_to_cam = torch.tensor([
    [-1,  0,  0],  
    [ 0, -1,  0],  
    [ 0,  0,  1], 
], dtype=torch.float32)

def transform_mesh_vertices(vertices, rotation, translation, scale):
    """
    Transform mesh vertices from local object space to world/camera frame:

    1. Flip Z-axis ( depending on GLB orientation)
    2. Convert from Y-up (GLB) to Z-up (canonical PyTorch3D frame)
    3. Apply GS outputs: scale, rotation, translation
    4. Convert back to Y-up for GLB export
    """

    if isinstance(vertices, np.ndarray):
        vertices = torch.tensor(vertices, dtype=torch.float32)

    vertices = vertices.unsqueeze(0)  #  batch dimension [1, N, 3]

    # Flip Z-axis
    vertices = vertices @ R_flip_z.to(vertices.device) 

    # Convert mesh from Y-up (GLB) → Z-up (canonical PyTorch3D)
    vertices = vertices @ R_yup_to_zup.to(vertices.device)

    # apply gaussian splatting transformations 
    R_mat = quaternion_to_matrix(rotation.to(vertices.device))
    tfm = Transform3d(dtype=vertices.dtype, device=vertices.device)
    tfm = (
        tfm.scale(scale)
           .rotate(R_mat)
           .translate(translation[0], translation[1], translation[2])
    )
    vertices_world = tfm.transform_points(vertices)

    # convert back to Y-up so GLB is saved correctly
    vertices = vertices @ R_zup_to_yup.to(vertices.device)

    # remove batch dimension
    return vertices_world[0]  


for i, out in enumerate(outputs):
    mesh = out["glb"]
    vertices = mesh.vertices

    vertices_tensor = torch.tensor(vertices)

    S = out["scale"][0].cpu().float()
    T = out["translation"][0].cpu().float()
    R = out["rotation"].squeeze().cpu().float()

    # Transform vertices
    vertices_transformed = transform_mesh_vertices(vertices, R, T, S)
  
    # --- Convert vertices from pointmap frame back to true camera frame ---
    # (undoing the earlier pointmap conversion: [-X, -Y, Z])
    vertices_transformed = vertices_transformed @ R_pytorch3d_to_cam.to(vertices_transformed.device)

    # Update mesh vertices
    mesh.vertices = vertices_transformed.cpu().numpy().astype(np.float32)

    # Export mesh
    save_path = f"{PATH}/meshes/multi/{IMAGE_NAME}/object_{i}.ply"
    os.makedirs(os.path.dirname(save_path), exist_ok=True)
    mesh.export(save_path)

# %% [markdown]
# ## 4. Visualize Gaussian Splat of the Scene
# ### a. Animated Gif

# %%
scene_gs = make_scene(*outputs)
scene_gs = ready_gaussian_for_video_rendering(scene_gs,fix_alignment=False)

# export gaussian splatting (as point cloud)
scene_gs.save_ply(f"{PATH}/gaussians/multi/{IMAGE_NAME}.ply")

video = render_video(
    scene_gs,
    r=1,
    fov=60,
    resolution=512,
)["color"]

# save video as gif
imageio.mimsave(
    os.path.join(f"{PATH}/gaussians/multi/{IMAGE_NAME}.gif"),
    video,
    format="GIF",
    duration=1000 / 30,  # default assuming 30fps from the input MP4
    loop=0,  # 0 means loop indefinitely
)

# notebook display
ImageDisplay(url=f"gaussians/multi/{IMAGE_NAME}.gif?cache_invalidator={uuid.uuid4()}",)
# Out:
# Rendering: 300it [00:05, 58.09it/s]
# <img src="gaussians/multi/nocs_0003_0354.gif?cache_invalidator=cecb0fb4-a202-42e3-bfb4-f915461175c5"/>

# %% [markdown]
# ### b. Interactive Visualizer

# %%
# might take a while to load (black screen)
interactive_visualizer(f"{PATH}/gaussians/single/{IMAGE_NAME}.ply")
# Out:
# * Running on local URL:  http://127.0.0.1:7860
#
# Could not create share link. Missing file: /home/ubuntu/.cache/huggingface/gradio/frpc/frpc_linux_amd64_v0.3.
#
# Please check your internet connection. This can happen if your antivirus software blocks the download of this file. You can install manually by following these steps:
#
# 1. Download this file: https://cdn-media.huggingface.co/frpc-gradio-0.3/frpc_linux_amd64
# 2. Rename the downloaded file to: frpc_linux_amd64_v0.3
# 3. Move the file to this location: /home/ubuntu/.cache/huggingface/gradio/frpc
# <div><iframe src="http://127.0.0.1:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
